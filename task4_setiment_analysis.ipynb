# %%
# ==========================================
# TASK-4 : SENTIMENT ANALYSIS USING NLP
# CODTECH INTERNSHIP
# ==========================================

# Install Required Libraries!pip install nltk textblob scikit-learn pandas

# %%
# Import Libraries
import pandas as pd
import nltk
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Download NLTK Data
nltk.download('punkt')

# ==========================================
# Create Dataset
# ==========================================

data = {
    'Review': [
        'I love this product',
        'This is the worst service ever',
        'Amazing experience',
        'I am very disappointed',
        'The food was delicious',
        'Bad quality item',
        'Excellent customer support',
        'Not worth the money',
        'Very happy with the purchase',
        'Terrible experience',
        'Fantastic application',
        'I hate this app',
        'Best movie ever',
        'Waste of money',
        'Highly recommended',
        'Very poor performance',
        'I enjoyed using this',
        'Awful customer service',
        'Superb quality',
        'Not good at all'
    ],

    'Sentiment': [
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative',
        'Positive',
        'Negative'
    ]
}



# Create DataFrame
df = pd.DataFrame(data)

print("===== DATASET =====")
print(df)

# ==========================================
# Data Preprocessing
# ==========================================

vectorizer = CountVectorizer(stop_words='english')

X = vectorizer.fit_transform(df['Review'])

y = df['Sentiment']

# ==========================================
# Split Dataset
# ==========================================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)


# ==========================================
# Train Model
# ==========================================

model = MultinomialNB()

model.fit(X_train, y_train)

# ==========================================
# Prediction
# ==========================================

y_pred = model.predict(X_test)

print("\n===== PREDICTED SENTIMENTS =====")
print(y_pred)

# ==========================================
# Accuracy
# ==========================================

accuracy = accuracy_score(y_test, y_pred)

print("\n===== MODEL ACCURACY =====")
print("Accuracy:", accuracy)

# ==========================================
# Classification Report
# ==========================================

print("\n===== CLASSIFICATION REPORT =====")
print(classification_report(y_test, y_pred, zero_division=1))

# ==========================================
# Custom Review Testing
# ==========================================

sample = ["The product quality is amazing"]

sample_data = vectorizer.transform(sample)

prediction = model.predict(sample_data)

print("\n===== CUSTOM REVIEW TEST =====")
print("Review:", sample[0])
print("Predicted Sentiment:", prediction[0])

# ==========================================
# TextBlob Sentiment Analysis
# ==========================================

text = "I really enjoyed the movie"

blob = TextBlob(text)

print("\n===== TEXTBLOB SENTIMENT ANALYSIS =====")
print("Text:", text)
print("Polarity:", blob.sentiment.polarity)

if blob.sentiment.polarity > 0:
    print("Positive Sentiment")

elif blob.sentiment.polarity < 0:
    print("Negative Sentiment")

else:
    print("Neutral Sentiment")

print("\n===== CONCLUSION =====")
print("Sentiment Analysis was successfully performed using NLP techniques.")
print("The model was trained using Naive Bayes Classification.")
print("The system can classify text as Positive or Negative.")

# ==========================================
# END OF PROJECT
# ==========================================
# Out:
# ===== DATASET =====
#                             Review Sentiment
# 0              I love this product  Positive
# 1   This is the worst service ever  Negative
# 2               Amazing experience  Positive
# 3           I am very disappointed  Negative
# 4           The food was delicious  Positive
# 5                 Bad quality item  Negative
# 6       Excellent customer support  Positive
# 7              Not worth the money  Negative
# 8     Very happy with the purchase  Positive
# 9              Terrible experience  Negative
# 10           Fantastic application  Positive
# 11                 I hate this app  Negative
# 12                 Best movie ever  Positive
# 13                  Waste of money  Negative
# 14              Highly recommended  Positive
# 15           Very poor performance  Negative
# 16            I enjoyed using this  Positive
# 17          Awful customer service  Negative
# 18                  Superb quality  Positive
# ...
